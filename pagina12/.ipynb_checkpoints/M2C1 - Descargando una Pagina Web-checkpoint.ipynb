rodrigo Fresán</a></li><li><a href="/292009-ese-silencio-no-es-salud">Saulo Dalmasso</a></li><li><a href="/autores/5997-silvina-friera">Silvina Friera</a></li><li><a href="/autores/1238-sonia-santoro">Sonia Santoro</a></li><li><a href="/autores/1243-victor-wolf">Victor Wolf</a></li><li><a href="/autores/1246-werner-pertot">Werner Pertot</a></li></ul><div class="read-more hidden"><span class="label-more">Ver más</span><span class="hidden label-less">Ver menos</span><span class="caret bottom"></span><span class="caret top hidden"></span></div></div></div></div><div class="hide-for-large"><div class="widget authorsOfToday authorsOfToday--mobile"><div class="authorsOfToday--top"><div class="column right"><div class="read-more hidden"><span class="label-more">Ver más</span><span class="hidden label-less">Ver menos</span><span class="caret bottom"></span><span class="caret top hidden"></span></div></div><div class="column left"><div class="title">Escriben hoy:</div></div></div><div class="divider"></div><div class="list-container"><ul class=" ...
# "><li class="twitter"><span class="share fonticon-twitter"></span></li><li class="facebook"><span class="share fonticon-facebook"></span></li><li class="mail"><span class="share fonticon-mail"></span></li></li></ul></div><div class="pirulo-label"><div class="pirulo-label-deco"></div><a href="https://www.pagina12.com.ar/pirulo/292119">FIESTA</a></div></div><div class="pirulo-block-middle"><p>El sábado, el titular del Centro de Operaciones de Emergencias de Villa Giardino, en Córdoba, se presentó en una casa en la que se estaba llevando a cabo una fiesta no autorizada. Para su sorpresa, la anfitriona era Verónica Campos, encargada de la Inspectoría General de la Municipalidad, es decir, parte del dispositivo que se ocupa de controlar el cumplimiento de la cuarentena. El funcionario reclamó ante el intendente la renuncia de Campos, que finalmente se produjo. El escándalo creció cuando los portales locales revelaron el motivo por el que la inspectora general no se resistió a hacer un festejo: era el cumpleaños de su perro.</p>
# </div><div class="pirulo-block-bottom"><div class="pirulo-social hide-for-large"><ul class="social-media big" share-data="pirulo" share-url="https://www.pagina12.com.ar/pirulo/292119" share-title="FIESTA" share-desc="El sábado, el titular del Centro de Operaciones de Emergencias de Villa Giardino, en Córdoba, se presentó en una casa en la que se estaba llevando a cabo una fiesta no autorizada. Para su sorpresa, la anfitriona era Verónica Campos, encargada de la ..." share-img="https://www.pagina12.com.ar/assets/media/FallBack-Logo.jpg" share-body="&lt;p&gt;El sábado, el titular del Centro de Operaciones de Emergencias de Villa Giardino, en Córdoba, se presentó en una casa en la que se estaba llevando a cabo una fiesta no autorizada. Para su sorpresa, la anfitriona era Verónica Campos, encargada de la Inspectoría General de la Municipalidad, es decir, parte del dispositivo que se ocupa de controlar el cumplimiento de la cuarentena. El funcionario reclamó ante el intendente la renuncia de Campos, que finalmente se produjo. El escándalo creció cuando los portales locales revelaron el motivo por el que la inspectora general no se resistió a hacer un festejo: era el cumpleaños de su perro.&lt;/p&gt;
# "><li class="twitter"><span class="share fonticon-twitter big"></span></li><li class="facebook"><span class="share fonticon-facebook big"></span></li><li class="mail"><span class="share fonticon-mail big"></span></li><li class="whatsapp hide-for-medium"><span class="share fonticon-whatsapp big"></span></li><li class="telegram hide-for-medium"><span class="share fonticon-telegram big"></span></li></ul></div></div></div></div></div></div></div></div><div class="text-center iframe-margin-top hide-for-medium"><div id="div-gpt-ad-1506537706019-0"></div></div></div><div class="wrapper"><div class="expand-horizontal-sm"><div class="layout-region region-2x2 tradicional sm-horiz"><div class="row headlines-block"><div class="headlines-block-col fixed-w left flex show-for-large"><div class="central bottom-auto ad-bg ad-bg--600"><div id="div-gpt-ad-1519672027502-0"></div></div></div><div class="headlines-block-col dynamic-w"><div class="headlines-block-row"><div class="small-12 medium-6 headline-list-mobile"> <div class="headline-card headline-2 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/292093-victor-hugo-morales-y-relatores-trabajaran-junto-al-equipo-d"><div class="intrinsic-container"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.234" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-09/104862-whatsapp-20image-202020-09-14-20at-2016-22-31.jpeg?itok=LYcKZfjk" alt="Víctor Hugo Morales no cobrará un solo peso por relatar los partidos."><img class="show-for-medium-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.234" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-09
="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-09/104754-mariana-20michi-20prensa.jpg?itok=D05zRCBM" alt="&quot;Las redes sociales piden constantemente generar contenido, pero eso no respeta el tiempo de maduración de una obra&quot;, dice."></div></a></div></div><div class="block-content"><div class="headline-content"><div class="headline-plaque"><div class="suplement-logo suplement-no"></div></div><div class="article-title "><a href="https://www.pagina12.com.ar/291996-mariana-michi-hay-paradigmas-y-formas-que-ya-no-sirven" ">"Hay paradigmas y formas que ya no <span class="title-separator">sirven"</span> <span class="title-prefix">Mariana Michi presenta su show La paz obligada</span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Sergio Sánchez</a></span></div></div></div></article></div></div><div class="columns small-12 medium-3"><div class="headline-card headline-1 decorated multimedia"><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/291995-de-wos ...

# %%
p12.content
# Out:
# b'<!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>P\xc3\xa1gina12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="P\xc3\xa1gina12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="twitter:title" name="twitter:title" content="P\xc3\xa1gina12 | La otra mirada"><meta property="twitter:description" name="twitter:description" content="Notas focalizadas en el quehacer pol\xc3\xadtico de la Argentina."><meta property="twitter:creator" name="twitter:creator" content="@Pagina12"><meta property="twitter:site" name="twitter:site" content="@pagina12"><meta property="article:author" name="article:author" content="P\xc3\xa1gina12"><meta property="article:publisher" name="article:publisher" content="https://www.facebook.com/Pagina12ok"><meta name="share_cdn_host" content="https://www.pagina12.com.ar"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" /><link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.234" media="screen"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.234" media="print"><link rel="shortcut icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.234" type="image/x-icon"><link rel="icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.234" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.234"><link rel="apple-touch-icon" sizes="72x72" href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.234"><link rel="apple-touch-icon" sizes="114x114" href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.234"><link rel="apple-touch-icon" sizes="120x120" href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.234"><link rel="apple-touch-icon" sizes="144x144" href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.234"><link rel="apple-touch-icon" sizes="152x152" href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.234"><script>dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,document,\'script\',\'dataLayer\',\'GTM-THCQP5X\');</script><script type=\'text/javascript\'>(function() {var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});_sf_async_config[\'uid\'] = 65120;_sf_async_config[ ...

# %%
p12.headers
# Out:
# {'Date': 'Tue, 15 Sep 2020 22:51:46 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=de997e84b589868425c375393bd4a2f941600210306; expires=Thu, 15-Oct-20 22:51:46 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-ETag': 'W/"5d8b5-O7eI4nJeX/qHoqzjkWtd9T5n5hM"', 'X-Backend': 'frontend', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '1', 'grace': '86400.000 none', 'ttl': '118.793', 'X-Instance': 'cache-front-prod-varnish-748c8f559f-vvnr9', 'x-restarts': '0', 'X-Cache': 'HIT (8)', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '0535909d6d0000b2a83aab3200000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '5d35ea0f1ad5b2a8-MEX', 'Content-Encoding': 'gzip'}

# %%
p12.request.headers #Encabezado con el que sale esta solicitud
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
p12.request.method #Con esto podemos saber que metodo GET que utilizamos para obtener informacion.
# Out:
# 'GET'

# %%
p12.request.url #Consultando la URL a la que estamos conectando
# Out:
# 'https://www.pagina12.com.ar/'

# %%
from bs4 import BeautifulSoup
#Esta biblioteca nos permite parsear el codigo HTML, es decir, agarramos todo el texto plano de nuestro sitio web
#y poder identificar distintas partes en donde estara la informacion que nos interesa

# %%
s = BeautifulSoup(p12.text, 'lxml')
# Out:
# ------------------------------------------------
# FeatureNotFoundTraceback (most recent call last)
# <ipython-input-30-137325432e46> in <module>
# ----> 1 s = BeautifulSoup(p12.text, 'lxml')
#
# ~/anaconda3/envs/pagina12_env/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     240             builder_class = builder_registry.lookup(*features)
#     241             if builder_class is None:
# --> 242                 raise FeatureNotFound(
#     243                     "Couldn't find a tree builder with the features you "
#     244                     "requested: %s. Do you need to install a parser library?"
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
# Out:
# ------------------------------------------------
# NameError      Traceback (most recent call last)
# <ipython-input-27-2ad6485b65ee> in <module>
# ----> 1 Yes
#
# NameError: name 'Yes' is not defined
